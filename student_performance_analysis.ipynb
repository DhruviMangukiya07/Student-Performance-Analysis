# %%
#  Student Performance Analysis
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
data = {
    'Name':['Dhruvi','Rahul','Priya','Aman','Neha','Karan','Riya','Vishal','Sneha','Jay'],
    'Subject':['Python','SQL','Python','Excel','SQL','Power BI','Python','Excel','SQL','Power BI'],
    'Marks':[90,75,95,60,85,70,29,65,39,78],
    'Hours_Studied':[5,3,6,2,4,3,5,2,6,4]
}

df = pd.DataFrame(data)

print("80+ marks students:",df[df['Marks']>80])

print("Average Marks:",df['Marks'].mean())

print("Highest Marks student:",df.loc[df['Marks'].idxmax()])

print("Lowest Marks student:",df.loc[df['Marks'].idxmin()])

Subject_avg = df.groupby('Subject')['Marks'].mean()
print(Subject_avg)

df['Result'] = df['Marks'].apply(
 lambda x:'pass' 
 if x >= 40
 else 'fail'
)
print(df)

sns.barplot(x = 'Subject',y = 'Marks',data = df,color='yellow')
plt.title('Average marks by subject')
plt.show()

sns.countplot(x = 'Result',data = df)
plt.title('Pass vs Fail')
plt.show()

sns.scatterplot(x = 'Hours_Studied',y = 'Marks',data = df)
plt.title('Hours studied vs marks')
plt.show()

sns.histplot(df['Marks'],bins = 5,kde = True,color = 'pink')
plt.title('Distribution of marks')
plt.show()

corr = df[['Marks','Hours_Studied']].corr()
sns.heatmap(corr,annot = True,cmap = 'coolwarm')
plt.show()
# Out:
# 80+ marks students:      Name Subject  Marks  Hours_Studied
# 0  Dhruvi  Python     90              5
# 2   Priya  Python     95              6
# 4    Neha     SQL     85              4
# Average Marks: 68.6
# Highest Marks student: Name              Priya
# Subject          Python
# Marks                95
# Hours_Studied         6
# Name: 2, dtype: object
# Lowest Marks student: Name               Riya
# Subject          Python
# Marks                29
# Hours_Studied         5
# Name: 6, dtype: object
# Subject
# Excel       62.500000
# Power BI    74.000000
# Python      71.333333
# SQL         66.333333
# Name: Marks, dtype: float64
#      Name   Subject  Marks  Hours_Studied Result
# 0  Dhruvi    Python     90              5   pass
# 1   Rahul       SQL     75              3   pass
# 2   Priya    Python     95              6   pass
# 3    Aman     Excel     60              2   pass
# 4    Neha       SQL     85              4   pass
# 5   Karan  Power BI     70              3   pass
# 6    Riya    Python     29              5   fail
# 7  Vishal     Excel     65              2   pass
# 8   Sneha       SQL     39              6   fail
# 9     Jay  Power BI     78              4   pass

# %%
# Out:
# Total expense: 2970
# Highest expense:
#  Date        2026-06-03
# Category      Shopping
# Amount            1500
# Name: 2, dtype: object
# Lowest expense:
#  Date        2026-06-02
# Category        Travel
# Amount             100
# Name: 1, dtype: object
# Expense above ₹500:
#           Date  Category  Amount
# 2  2026-06-03  Shopping    1500
# 4  2026-06-05     Bills     800
# Category
# Bills        800
# Food         450
# Shopping    1500
# Travel       220
# Name: Amount, dtype: int64
# Average expense: 495.0
#          Date  Category  Amount Expense_type
# 0  2026-06-01      Food     200       Normal
# 1  2026-06-02    Travel     100       Normal
# 2  2026-06-03  Shopping    1500         High
# 3  2026-06-04      Food     250       Normal
# 4  2026-06-05     Bills     800         High
# 5  2026-06-06    Travel     120       Normal
# Shopping
